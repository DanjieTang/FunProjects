# %%
from openai import OpenAI

client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio", timeout=60)

# %%
from pprint import pprint
from olmocr.pipeline import build_page_query

query = await build_page_query("./CM selection and bringup Play Book V1.42.pdf",
                               page=15,
                               target_longest_image_dim=1024,
                               target_anchor_text_len=6000)
# Out:
# WARNING:pypdf._reader:Ignoring wrong pointing object 17 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 25 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 77 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 84 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 122 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 184 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 209 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 215 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 226 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 234 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 245 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 253 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 281 0 (offset 0)
# ...

# %%
query['model'] = 'allenai_olmocr-7b-0225-preview'
response = client.chat.completions.create(**query)

print(response.choices[0].message.content)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:1234/v1/chat/completions "HTTP/1.1 200 OK"
# {"primary_language":"en","is_rotation_valid":true,"rotation_correction":0,"is_table":false,"is_diagram":true,"natural_text":"CM Playbook | Process overview\n\n3 Phases Overview\n\n- Initial down selection: CM Assessment\n  - IDL: Company culture, Leadership, Hiring strategy\n- CM Bring up: Facility\n  - Facility location, Faculty space design for efficiency\n- CM Performance review: Equipment\n  - Equipment investment, Equipment readiness\n\nEngineering focus"}
